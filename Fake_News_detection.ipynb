# %%
import pandas as pd
import numpy as np

false = pd.read_csv('/content/Fake.csv')
true = pd.read_csv('/content/True.csv')

# %%
true
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...     worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...     worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...     worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...     worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...     worldnews
#
#                      date
# 0      December 31, 2017
# 1      December 29, 2017
# 2      December 31, 2017
# 3      December 30, 2017
# 4      December 29, 2017
# ...                   ...
# 21412    August 22, 2017
# 21413    August 22, 2017
# 21414    August 22, 2017
# 21415    August 22, 2017
# 21416    August 22, 2017
#
# [21417 rows x 4 columns]

# %%
false.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true['label']=1
false['label']=0

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
news= pd.concat([false,true],axis=0)

# %%
news
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 0      Donald Trump just couldn t wish all Americans ...       News
# 1      House Intelligence Committee Chairman Devin Nu...       News
# 2      On Friday, it was revealed that former Milwauk...       News
# 3      On Christmas day, Donald Trump announced that ...       News
# 4      Pope Francis used his annual Christmas Day mes...       News
# ...                                                  ...        ...
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                     date  label
# 0      December 31, 2017      0
# 1      December 31, 2017      0
# 2      December 30, 2017      0
# 3      December 29, 2017      0
# 4      December 25, 2017      0
# ...                  ...    ...
# 21412   August 22, 2017       1
# 21413   August 22, 2017       1
# 21414   August 22, 2017       1
# 21415   August 22, 2017       1
# 21416   August 22, 2017       1
#
# [44898 rows x 5 columns]

# %%
news =news.drop(['title','subject','date'],axis=1)

# %%
print(news)
# Out:
#                                                     text  label
# 0      Donald Trump just couldn t wish all Americans ...      0
# 1      House Intelligence Committee Chairman Devin Nu...      0
# 2      On Friday, it was revealed that former Milwauk...      0
# 3      On Christmas day, Donald Trump announced that ...      0
# 4      Pope Francis used his annual Christmas Day mes...      0
# ...                                                  ...    ...
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...      1
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...      1
# 21414  MINSK (Reuters) - In the shadow of disused Sov...      1
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...      1
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...      1
#
# [44898 rows x 2 columns]

# %%
news = news.sample(frac=1)   #reshuffling
news
# Out:
#                                                     text  label
# 3360   Reality show star turned president-elect Donal...      0
# 21020  BRASILIA (Reuters) - A leniency deal struck be...      1
# 17534  Last week, President Trump totally humiliated ...      0
# 1553   Remember when Trump said that we were done wit...      0
# 3215   WASHINGTON (Reuters) - U.S. Secretary of State...      1
# ...                                                  ...    ...
# 503    During Donald Trump s meltdown during his rall...      0
# 23460   Patrick Henningsen 21st Century WireThere exi...      0
# 12365  ROME (Reuters) - Italy s parliament will be di...      1
# 8619   Michigan s governor Rick Snyder is desperately...      0
# 19770  HANOI (Reuters) - Vietnam s ruling party watch...      1
#
# [44898 rows x 2 columns]

# %%
news.reset_index(inplace=True)

# %%
news.head()
# Out:
#    index                                               text  label
# 0   3360  Reality show star turned president-elect Donal...      0
# 1  21020  BRASILIA (Reuters) - A leniency deal struck be...      1
# 2  17534  Last week, President Trump totally humiliated ...      0
# 3   1553  Remember when Trump said that we were done wit...      0
# 4   3215  WASHINGTON (Reuters) - U.S. Secretary of State...      1

# %%
news.drop(['index'],axis=1,inplace=True)

# %%
news
# Out:
#                                                     text  label
# 0      Reality show star turned president-elect Donal...      0
# 1      BRASILIA (Reuters) - A leniency deal struck be...      1
# 2      Last week, President Trump totally humiliated ...      0
# 3      Remember when Trump said that we were done wit...      0
# 4      WASHINGTON (Reuters) - U.S. Secretary of State...      1
# ...                                                  ...    ...
# 44893  During Donald Trump s meltdown during his rall...      0
# 44894   Patrick Henningsen 21st Century WireThere exi...      0
# 44895  ROME (Reuters) - Italy s parliament will be di...      1
# 44896  Michigan s governor Rick Snyder is desperately...      0
# 44897  HANOI (Reuters) - Vietnam s ruling party watch...      1
#
# [44898 rows x 2 columns]

# %%
import re

# %%
def wordopt(text):
  # converting to lower case
  text = text.lower()

  # to remove the URLs
  text = re.sub(r'https?://\S+|www.\.\S+','',text)

  #remove HTML tags
  text = re.sub(r'<.*?>','',text)

  #remove punctuation
  text = re.sub(r'[^\w\s]','',text)

  #remove digits
  text = re.sub(r'\d' ,'', text )

  #remove newline characters

  text= re.sub(r'\n',' ',text)

  return text

# %%
news['text'] = news['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0        reality show star turned presidentelect donald...
# 1        brasilia reuters  a leniency deal struck betwe...
# 2        last week president trump totally humiliated a...
# 3        remember when trump said that we were done wit...
# 4        washington reuters  us secretary of state rex ...
#                                ...
# 44893    during donald trump s meltdown during his rall...
# 44894     patrick henningsen st century wirethere exist...
# 44895    rome reuters  italy s parliament will be disso...
# 44896    michigan s governor rick snyder is desperately...
# 44897    hanoi reuters  vietnam s ruling party watchdog...
# Name: text, Length: 44898, dtype: object

# %%
x = news['text']
y = news['label']

# %%
x
# Out:
# 0        reality show star turned presidentelect donald...
# 1        brasilia reuters  a leniency deal struck betwe...
# 2        last week president trump totally humiliated a...
# 3        remember when trump said that we were done wit...
# 4        washington reuters  us secretary of state rex ...
#                                ...
# 44893    during donald trump s meltdown during his rall...
# 44894     patrick henningsen st century wirethere exist...
# 44895    rome reuters  italy s parliament will be disso...
# 44896    michigan s governor rick snyder is desperately...
# 44897    hanoi reuters  vietnam s ruling party watchdog...
# Name: text, Length: 44898, dtype: object

# %%
y
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        1
#         ..
# 44893    0
# 44894    0
# 44895    1
# 44896    0
# 44897    1
# Name: label, Length: 44898, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train , x_test,y_train , y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (31428,)

# %%
x_test.shape
# Out:
# (13470,)

# %%
# !pip install scikit-learn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.4.0)

# %%
vectorization = TfidfVectorizer()

# %%
 xv_train = vectorization.fit_transform(x_train)

# %%
xv_test = vectorization.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()

# %%
LR.fit(xv_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test, y_test)
# Out:
# 0.9884929472902747

# %%
print(classification_report(y_test,pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7079
#            1       0.98      0.99      0.99      6391
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTC = DecisionTreeClassifier()

# %%
DTC.fit(xv_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc = DTC.predict(xv_test)

# %%
DTC.score(xv_test, y_test)
# Out:
# 0.9955456570155902

# %%
print(classification_report(y_test,pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7079
#            1       1.00      1.00      1.00      6391
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(xv_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred_rfc = rfc.predict(xv_test)

# %%
rfc.score(xv_test , y_test)
# Out:
# 0.9882702301410542

# %%
print(classification_report(y_test,pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7079
#            1       0.98      0.99      0.99      6391
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc=GradientBoostingClassifier()

# %%
gbc.fit(xv_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
gbc.score( xv_test , y_test )
pred_gbc = gbc.predict(xv_test)

# %%
print(classification_report(y_test ,pred_gbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      7079
#            1       0.99      1.00      1.00      6391
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
def output_label(n):
  if n==0:
    return "It is a fake news"
  elif n==1:
    return " It is a Genuine news"

# %%
def manual_testing(news):
  testing_news ={"text" :[news]}
  new_def_test = pd.DataFrame(testing_news)
  new_def_test["text"] = new_def_test["text"].apply(wordopt)
  new_x_test = new_def_test['text']
  new_xv_test = vectorization.transform(new_x_test)
  pred_lr = LR.predict(new_xv_test)
  pred_gbc =gbc.predict(new_xv_test)
  pred_rfc =rfc.predict(new_xv_test)
  return "\n\nLR Prediction : {}  \nGBC Prediction: {} \nRFC Prediction: {}".format(output_label(pred_lr[0]) , output_label(pred_gbc[0]) , output_label(pred_rfc[0]))

# %%
news_artical = str(input())
# Out:
# WASHINGTON (Reuters) - New York State Attorney Eric Schneiderman on Tuesday said he has been investigating for six months who posted significant numbers of fake comments filed with the Federal Communications Commission in its review of net neutrality rules. The FCC got more than 22 million comments during its review and several researchers found evidence that significant numbers of submissions were fake.  Schneiderman said Tuesday the â€œFCC has refused multiple requests for crucial evidence.â€  The FCC did not immediately comment.  On Tuesday FCC Chairman Ajit Pai proposed reversing the Obama era net neutrality rules.

# %%
manual_testing(news_artical)
# Out:
# '\n\nLR Prediction :  It is a Genuine news  \nGBC Prediction:  It is a Genuine news \nRFC Prediction:  It is a Genuine news'
